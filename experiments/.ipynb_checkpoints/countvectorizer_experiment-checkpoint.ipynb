# %%
import pandas as pd
# Import TfIdfVectorizer from scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load Movies Metadata
data = pd.read_csv('../leetcode_data_processed.csv', low_memory=False)

# %%
count_vec = CountVectorizer(stop_words='english')
data['content'] = data['content'].fillna('')
count_mat = count_vec.fit_transform(data['content'])
count_mat.shape
# Out:
# (874, 2858)

# %%
count_vec.vocabulary_
# Out:
# {'square': 2387,
#  'cell': 340,
#  'blocked': 226,
#  'length': 1369,
#  'composed': 464,
#  'cells': 341,
#  'adjacent': 39,
#  'connected': 482,
#  'different': 687,
#  'edge': 775,
#  'location': 1426,
#  'value': 2732,
#  'located': 1425,
#  'return': 2128,
#  'shortest': 2281,
#  'clear': 396,
#  'path': 1764,
#  'example': 867,
#  'given': 1054,
#  'strings': 2447,
#  'string': 2446,
#  'multiple': 1577,
#  'answers': 91,
#  'subsequence': 2472,
#  'deleting': 633,
#  'number': 1634,
#  'characters': 358,
#  'chosen': 377,
#  'results': 2124,
#  'substring': 2477,
#  'delete': 630,
#  'answer': 89,
#  'provided': 1938,
#  'satisfies': 2203,
#  'consist': 494,
#  'lowercase': 1455,
#  'english': 817,
#  'set': 2263,
#  'item': 1285,
#  'label': 1327,
#  'subset': 2475,
#  'items': 1286,
#  'largest': 1345,
#  'possible': 1863,
#  'sum': 2488,
#  'values': 2734,
#  'labels': 1331,
#  'fifth': 940,
#  'fourth': 1008,
#  'fixed': 961,
#  'arr': 118,
#  'duplicate': 764,
#  'occurrence': 1663,
#  'shifting': 2273,
#  'remaining': 2066,
#  'elements': 789,
#  'note': 1627,
#  'original': 1695,
#  'array': 123,
#  'modifications': 1555,
#  'input': 1223,
#  'calling': 299,
#  'modified': 1556,
#  'tile': 2570,
#  'letter': 1373,
#  'printed': 1907,
#  'sequences': 2253,
#  'letters': 1374,
#  'tiles': 2571,
#  'consists': 497,
#  'uppercase': 2712,
#  'lexicographically': 1380,
#  'smallest': 2337,
#  'text': 2553,
#  'contains': 512,
#  'distinct': 716,
#  'exactly': 864,
#  'binary': 215,
#  'consider': 491,
#  'root': 2166,
#  'leaf': 1356,
#  'paths': 1765,
#  'node': 1621,
#  'insufficient': 1242,
#  'intersecting': 1263,
#  'strictly': 2445,
#  'nodes': 1622,
#  'limit': 1393,
#  'tree': 2630,
#  'words': 2816,
#  'occurrences': 1664,
#  'form': 995,
#  'second': 2225,
#  'comes': 435,
#  'immediately': 1171,
#  'add': 26,
#  'good': 1066,
#  'girl': 1053,
#  'rock': 2159,
#  'space': 2360,
#  'separated': 2249,
#  'word': 2812,
#  'numbers': 1636,
#  'base': 186,
#  'result': 2122,
#  'adding': 28,
#  'significant': 2296,
#  'bit': 218,
#  'represents': 2097,
#  'format': 997,
#  'guaranteed': 1091,
#  'leading': 1355,
#  'output': 1703,
#  'zeros': 2854,
#  'matrix': 1496,
#  'consisting': 496,
#  'choose': 373,
#  'columns': 429,
#  'flip': 971,
#  'flipping': 973,
#  'changes': 354,
#  'maximum': 1505,
#  'rows': 2186,
#  'equal': 833,
#  'row': 2184,
#  'say': 2207,
#  'divides': 724,
#  'concatenated': 472,
#  'submatrices': 2466,
#  'submatrix': 2467,
#  'target': 2532,
#  'contain': 508,
#  'plus': 1838,
#  'barcode': 183,
#  'rearrange': 2015,
#  'barcodes': 184,
#  'positive': 1861,
#  'integers': 1245,
#  'necessarily': 1600,
#  'permutation': 1791,
#  'smaller': 2336,
#  'swap': 2508,
#  'exchanges': 874,
#  'positions': 1860,
#  'swapping': 2510,
#  'bookstore': 239,
#  'owner': 1717,
#  'store': 2433,
#  'open': 1675,
#  'customers': 587,
#  'enter': 820,
#  'leave': 1357,
#  'end': 804,
#  'grumpy': 1089,
#  'minute': 1545,
#  'knows': 1322,
#  'secret': 2227,
#  'technique': 2538,
#  'use': 2715,
#  'satisfied': 2202,
#  'keeps': 1312,
#  'students': 2455,
#  'asked': 134,
#  'stand': 2399,
#  'order': 1691,
#  'heights': 1122,
#  'annual': 87,
#  'minimum': 1541,
#  'standing': 2401,
#  'right': 2148,
#  'collection': 420,
#  'integer': 1244,
#  'smash': 2339,
#  'suppose': 2502,
#  'stones': 2428,
#  'weights': 2792,
#  'totally': 2594,
#  'stone': 2427,
#  'weight': 2791,
#  'new': 1614,
#  'combine': 432,
#  'converts': 532,
#  'optimal': 1685,
#  'list': 1405,
#  'predecessor': 1880,
#  'make': 1470,
#  'sequence': 2252,
#  'longest': 1440,
#  'chain': 347,
#  'removal': 2069,
#  'choosing': 375,
#  'repeatedly': 2079,
#  'removals': 2070,
#  'longer': 1439,
#  'final': 948,
#  'remove': 2071,
#  'duplicated': 765,
#  'substrings': 2478,
#  'occur': 1660,
#  'partition': 1752,
#  'subarrays': 2458,
#  'subarray': 2457,
#  'changed': 353,
#  'labelled': 1330,
#  'want': 2778,
#  'plant': 1827,
#  'types': 2669,
#  'describes': 654,
#  'existence': 888,
#  'bidirectional': 207,
#  'garden': 1037,
#  'coming': 436,
#  'leaving': 1359,
#  'task': 2534,
#  'flower': 980,
#  'type': 2667,
#  'gardens': 1038,
#  'choice': 371,
#  'infinite': 1211,
#  'initially': 1220,
#  'stands': 2402,
#  'faces': 914,
#  'robot': 2158,
#  'receive': 2021,
#  'straight': 2438,
#  'turn': 2656,
#  'degrees': 628,
#  'degress': 629,
#  'performs': 1784,
#  'instructions': 1241,
#  'repeats': 2081,
#  'true': 2646,
#  'exists': 890,
#  'circle': 381,
#  'plane': 1824,
#  'leaves': 1358,
#  'moves': 1572,
#  'turns': 2659,
#  'returns': 2131,
#  'repeating': 2080,
#  'remains': 2067,
#  'radius': 1980,
#  'centered': 344,
#  'false': 924,
#  'north': 1626,
#  'boomerang': 242,
#  'points': 1842,
#  'search': 2219,
#  'modify': 1558,
#  'greater': 1076,
#  'left': 1364,
#  'subtree': 2481,
#  'subtrees': 2482,
#  'position': 1858,
#  'endpoint': 808,
#  'pick': 1800,
#  'unoccupied': 2703,
#  'moving': 1573,
#  'game': 1034,
#  'ends': 810,
#  'consecutive': 488,
#  'finish': 953,
#  'notice': 1629,
#  'illegal': 1164,
#  'convex': 533,
#  'polygon': 1849,
#  'vertices': 2746,
#  'clockwise': 406,
#  'triangulate': 2635,
#  'triangle': 2633,
#  'total': 2593,
#  'score': 2215,
#  'triangulation': 2636,
#  'triangles': 2634,
#  'achieve': 17,
#  'million': 1533,
#  'coordinates': 542,
#  'grid': 1079,
#  'start': 2403,
#  'source': 2357,
#  'reach': 2003,
#  'walk': 2772,
#  'inaccessible': 1183,
#  'starting': 2406,
#  'outside': 1705,
#  'write': 2826,
#  'separate': 2248,
#  'horizontal': 1143,
#  'draw': 745,
#  'connecting': 483,
#  'line': 1396,
#  'intersect': 1261,
#  'lines': 1399,
#  'belong': 200,
#  'uncrossed': 2682,
#  'color': 425,
#  'squares': 2389,
#  'component': 461,
#  'boundary': 250,
#  'lowest': 1456,
#  'highest': 1130,
#  'currently': 584,
#  'implement': 1173,
#  'streamchecker': 2443,
#  'class': 395,
#  'init': 1216,
#  'data': 596,
#  'structure': 2452,
#  'queried': 1961,
#  'oldest': 1671,
#  'including': 1187,
#  'spell': 2370,
#  'queries': 1962,
#  'people': 1779,
#  'company': 447,
#  'planning': 1826,
#  'cost': 551,
#  'flying': 984,
#  'person': 1795,
#  'city': 393,
#  'fly': 983,
#  'arrive': 126,
#  'goes': 1062,
#  'half': 1100,
#  'interviewing': 1270,
#  'sorted': 2354,
#  'distance': 714,
#  'manhattan': 1476,
#  'distances': 715,
#  'accepted': 11,
#  'run': 2192,
#  'dashes': 595,
#  'depth': 647,
#  'immediate': 1170,
#  'child': 369,
#  'recover': 2035,
#  'ancestor': 83,
#  'various': 2739,
#  'obtained': 1654,
#  'arithmetic': 116,
#  'recall': 2020,
#  'steps': 2419,
#  'alice': 58,
#  'bob': 233,
#  'playing': 1834,
#  'player': 1832,
#  'makes': 1471,
#  'chalkboard': 348,
#  'lose': 1447,
#  'wins': 2810,
#  'assuming': 140,
#  'players': 1833,
#  'play': 1830,
#  'chooses': 374,
#  'series': 2260,
#  'video': 2749,
#  'clips': 404,
#  'sporting': 2382,
#  'event': 857,
#  'lasted': 1347,
#  'overlapping': 1711,
#  'varied': 2737,
#  'clip': 403,
#  'starts': 2407,
#  'time': 2575,
#  'cut': 588,
#  'segments': 2233,
#  'needed': 1603,
#  'cover': 564,
#  'entire': 824,
#  'reconstruct': 2028,
#  'extra': 910,
#  'query': 1963,
#  'matches': 1490,
#  'pattern': 1766,
#  'insert': 1226,
#  'equals': 835,
#  'character': 357,
#  'generated': 1044,
#  'like': 1390,
#  'lower': 1454,
#  'upper': 2711,
#  'case': 327,
#  'represent': 2091,
#  'represented': 2095,
#  'exceed': 869,
#  'valid': 2727,
#  'parentheses': 1741,
#  'primitive': 1902,
#  'exist': 887,
#  'way': 2786,
#  'split': 2379,
#  'nonempty': 1624,
#  'removing': 2075,
#  'outermost': 1701,
#  'decomposition': 612,
#  'outer': 1700,
#  'walking': 2774,
#  'land': 1336,
#  'enclosed': 797,
#  'linked': 1401,
#  'larger': 1344,
#  'arrays': 124,
#  'serialization': 2255,
#  'head': 1116,
#  'range': 1990,
#  'divisible': 726,
#  'returned': 2129,
#  'unless': 2698,
#  'representation': 2093,
#  'need': 1602,
#  'digit': 690,
#  'sightseeing': 2291,
#  'spots': 2383,
#  'pair': 1728,
#  'minus': 1544,
#  'parts': 1755,
#  'indexes': 1200,
#  'repeated': 2078,
#  'atleast': 147,
#  'conveyor': 534,
#  'belt': 202,
#  'packages': 1722,
#  'shipped': 2276,
#  'port': 1855,
#  'package': 1721,
#  'load': 1421,
#  'ship': 2275,
#  'capacity': 311,
#  'days': 598,
#  'cargo': 322,
#  'using': 2721,
#  'splitting': 2381,
#  'duration': 767,
#  'pairs': 1729,
#  'songs': 2352,
#  'seconds': 2226,
#  'zeroes': 2853,
#  'changing': 355,
#  'complement': 454,
#  'preorder': 1885,
#  'descendant': 651,
#  'traverses': 2626,
#  'halves': 1101,
#  'domino': 737,
#  'rotate': 2173,
#  'rotations': 2177,
#  'figure': 942,
#  'dominoes': 738,
#  'indicated': 1202,
#  'factorial': 917,
#  'product': 1922,
#  'instead': 1239,
#  'clumsy': 412,
#  'decreasing': 613,
#  'multiply': 1580,
#  'operations': 1681,
#  'rotation': 2176,
#  'divide': 721,
#  'subtract': 2479,
#  'applied': 106,
#  'usual': 2722,
#  'multiplication': 1579,
#  'division': 727,
#  'addition': 29,
#  'subtraction': 2480,
#  'processed': 1918,
#  'floor': 977,
#  'guarantees': 1093,
#  'defined': 623,
#  'fit': 958,
#  'following': 988,
#  'repeat': 2077,
#  'process': 1917,
#  'times': 2578,
#  'index': 1198,
#  'modifying': 1559,
#  'indices': 1204,
#  'change': 352,
#  'bolded': 235,
#  'flipped': 972,
#  'pieces': 1807,
#  'examples': 868,
#  'resulting': 2123,
#  'insertings': 1229,
#  'occurs': 1666,
#  'include': 1184,
#  'lamps': 1335,
#  'tells': 2542,
#  'lamp': 1334,
#  'illuminates': 1165,
#  'diagonals': 675,
#  'queen': 1959,
#  'share': 2269,
#  'corner': 546,
#  'performing': 1783,
#  'representing': 2096,
#  'lit': 1413,
#  'looks': 1443,
#  'piles': 1811,
#  'arranged': 120,
#  'pile': 1810,
#  'merging': 1523,
#  'merge': 1520,
#  'white': 2798,
#  'black': 222,
#  'rook': 2162,
#  'rules': 2190,
#  'cardinal': 319,
#  'directions': 700,
#  'direction': 699,
#  'reaches': 2006,
#  'captures': 316,
#  'opposite': 1684,
#  'colored': 426,
#  'pawn': 1768,
#  'rooks': 2163,
#  'friendly': 1020,
#  'pawns': 1769,
#  'capture': 314,
#  'able': 5,
#  'bishops': 217,
#  'blocking': 227,
#  'just': 1310,
#  'previous': 1897,
#  'constructed': 504,
#  'recursively': 2042,
#  'let': 1371,
#  'element': 788,
#  'create': 570,
#  'copy': 545,
#  'val': 2725,
#  'appended': 102,
#  'unique': 2691,
#  'rumor': 2191,
#  'secretly': 2228,
#  'town': 2598,
#  'judge': 1301,
#  'trusts': 2650,
#  'everybody': 860,
#  'properties': 1933,
#  'trust': 2649,
#  'squareful': 2388,
#  'perfect': 1780,
#  'permutations': 1792,
#  'differ': 684,
#  'containing': 511,
#  'simultaneously': 2306,
#  'flips': 974,
#  'required': 2101,
#  'matter': 1497,
#  'size': 2314,
#  'fresh': 1018,
#  'rotten': 2178,
#  'orange': 1688,
#  'minutes': 1546,
#  'elapse': 785,
#  'column': 428,
#  'rotting': 2179,
#  'happens': 1107,
#  'oranges': 1689,
#  'children': 370,
#  'cousins': 563,
#  'corresponding': 549,
#  'formed': 1000,
#  'broken': 260,
#  'calculator': 295,
#  'showing': 2283,
#  'perform': 1781,
#  'display': 711,
#  'displaying': 712,
#  'double': 741,
#  'operation': 1680,
#  'decrement': 614,
#  'relationships': 2061,
#  'takes': 2527,
#  'variable': 2735,
#  'assign': 135,
#  'satisfy': 2204,
#  'equation': 836,
#  'variables': 2736,
#  'digits': 691,
#  'shorter': 2280,
#  'prefix': 1883,
#  'vertical': 2744,
#  'traversal': 2625,
#  'running': 2193,
#  'touches': 2596,
#  'report': 2088,
#  'reported': 2089,
#  'reports': 2090,
#  'loss': 1450,
#  'assume': 138,
#  'according': 14,
#  'closed': 408,
#  'intervals': 1268,
#  'pairwise': 1730,
#  'disjoint': 707,
#  'intersection': 1264,
#  'interval': 1267,
#  'real': 2012,
#  'inputs': 1224,
#  'desired': 661,
#  'lists': 1412,
#  'april': 112,
#  'reset': 2107,
#  'default': 621,
#  'code': 414,
#  'definition': 626,
#  'method': 1526,
#  'permanently': 1789,
#  'modifies': 1557,
#  'correct': 547,
#  'country': 557,
#  'popular': 1853,
#  'train': 2604,
#  'planned': 1825,
#  'travelling': 2623,
#  'year': 2848,
#  'travel': 2621,
#  'day': 597,
#  'tickets': 2566,
#  'sold': 2344,
#  'pass': 1757,
#  'passes': 1759,
#  'allow': 63,
#  'dollars': 733,
#  'costs': 552,
#  'buy': 286,
#  'lets': 1372,
#  'bought': 247,
#  'covered': 565,
#  'spent': 2375,
#  'increasing': 1193,
#  'timebased': 2576,
#  'supports': 2501,
#  'int': 1243,
#  'stores': 2435,
#  'key': 1313,
#  'called': 297,
#  'timemap': 2577,
#  'timestamp': 2579,
#  'foo': 991,
#  'timestamps': 2580,
#  'test': 2549,
#  'ending': 806,
#  'obstacles': 1652,
#  'walks': 2775,
#  'coins': 418,
#  'coin': 417,
#  'parent': 1740,
#  'said': 2197,
#  'turbulent': 2655,
#  'comparison': 451,
#  'sign': 2292,
#  'perimeter': 1785,
#  'impossible': 1179,
#  'odd': 1668,
#  'numbered': 1635,
#  'jumps': 1309,
#  'forward': 1006,
#  'jump': 1306,
#  'legal': 1366,
#  'jumping': 1308,
#  'reached': 2005,
#  'similar': 2299,
#  'deduce': 617,
#  'closest': 410,
#  'origin': 1694,
#  'euclidean': 847,
#  'closer': 409,
#  'commonly': 444,
#  'preceding': 1879,
#  'calculate': 292,
#  'rational': 1998,
#  'denote': 641,
#  'general': 1042,
#  'portion': 1856,
#  'decimal': 605,
#  'expansion': 891,
#  'conventionally': 527,
#  'denoted': 642,
#  'round': 2180,
#  'representations': 2094,
#  'link': 1400,
#  'begin': 195,
#  'restriction': 2121,
#  'means': 1509,
#  'current': 583,
#  'goal': 1060,
#  'voyage': 2769,
#  'powerful': 1875,
#  'bound': 248,
#  'reverse': 2137,
#  'zero': 2852,
#  'pancake': 1734,
#  'sort': 2353,
#  'sorts': 2355,
#  'judged': 1302,
#  'install': 1234,
#  'cameras': 303,
#  'camera': 302,
#  'monitor': 1563,
#  'placed': 1819,
#  'image': 1167,
#  'shows': 2285,
#  'configurations': 479,
#  'absolute': 7,
#  'difference': 685,
#  'spellchecker': 2371,
#  'checker': 362,
#  'handles': 1105,
#  'categories': 333,
#  'spelling': 2373,
#  'wordlist': 2815,
#  'vowel': 2767,
#  'replacing': 2087,
#  'vowels': 2768,
#  'match': 1488,
#  'operates': 1679,
#  'precedence': 1878,
#  'univalued': 2695,
#  'single': 2307,
#  'expression': 906,
#  'operator': 1682,
#  'writing': 2827,
#  'adhere': 37,
#  'allowed': 64,
#  'unary': 2676,
#  'uses': 2720,
#  'operators': 1683,
#  'determine': 666,
#  'area': 114,
#  'rectangle': 2036,
#  'sides': 2290,
#  'parallel': 1737,
#  'actual': 22,
#  'tuple': 2653,
#  'width': 2801,
#  'ramp': 1983,
#  'achieved': 18,
#  'deletion': 634,
#  'deletions': 635,
#  'chose': 376,
#  'lexicographic': 1378,
#  'individually': 1207,
#  'blank': 224,
#  'contiguous': 518,
#  'backslash': 167,
#  'refers': 2049,
#  'complete': 455,
#  'possibly': 1864,
#  'completely': 457,
#  'level': 1375,
#  'far': 926,
#  'inclusive': 1188,
#  'levels': 1376,
#  'prison': 1911,
#  'occupied': 1657,
#  'vacant': 2724,
#  'neighbors': 1609,
#  'state': 2409,
#  'initial': 1217,
#  'described': 653,
#  'table': 2522,
#  'summarizes': 2490,
#  'installing': 1236,
#  'billboard': 212,
#  'steel': 2417,
#  'support': 2498,
#  'rods': 2160,
#  'welded': 2794,
#  'lengths': 1370,
#  'weld': 2793,
#  'height': 1121,
#  'subsets': 2476,
#  'require': 2100,
#  'reorder': 2076,
#  'alien': 59,
#  'surprisingly': 2505,
#  'lexicographicaly': 1381,
#  'lexicographical': 1379,
#  'common': 443,
#  'factor': 916,
#  'define': 622,
#  'equivalent': 838,
#  'function': 1029,
#  'determines': 667,
#  'trees': 2632,
#  'deck': 607,
#  'card': 318,
#  'cards': 320,
#  'face': 913,
#  'reveal': 2134,
#  'unrevealed': 2704,
#  'step': 2418,
#  'ordering': 1693,
#  'entry': 828,
#  'considered': 492,
#  'revealed': 2135,
#  'hour': 1147,
#  'elapsed': 786,
#  'power': 1874,
#  'bag': 171,
#  'token': 2589,
#  'used': 2716,
#  'potentially': 1870,
#  'ways': 2787,
#  'losing': 1449,
#  'gaining': 1032,
#  'tokens': 2590,
#  'place': 1818,
#  'coordinate': 541,
#  'point': 1839,
#  'shares': 2271,
#  'pushed': 1945,
#  'push': 1944,
#  'pop': 1851,
#  'popped': 1852,
#  'incrementing': 1194,
#  'shown': 2284,
#  'mountain': 1567,
#  'count': 554,
#  'subsequences': 2473,
#  'modulo': 1561,
#  'log': 1431,
#  'delimited': 636,
#  'alphanumeric': 70,
#  'identifier': 1156,
#  'varieties': 2738,
#  'logs': 1436,
#  'come': 434,
#  'ordered': 1692,
#  'ignoring': 1162,
#  'act': 20,
#  'stamp': 2397,
#  'replace': 2083,
#  'fully': 1028,
#  'contained': 509,
#  'boundaries': 249,
#  'stamped': 2398,
#  'specifying': 2368,
#  'chess': 367,
#  'knight': 1319,
#  'diagram': 676,
#  'phone': 1797,
#  'pad': 1724,
#  'hop': 1142,
#  'lands': 1339,
#  'placement': 1820,
#  'presses': 1893,
#  'pressing': 1894,
#  'dial': 678,
#  'island': 1280,
#  'group': 1085,
#  'connect': 481,
#  'islands': 1281,
#  'recentcounter': 2024,
#  'recent': 2023,
#  'pings': 1813,
#  'milliseconds': 1534,
#  'ago': 48,
#  'ping': 1812,
#  'calls': 300,
#  'beautiful': 193,
#  'falling': 922,
#  'email': 791,
#  'local': 1422,
#  'domain': 734,
#  'emails': 792,
#  'periods': 1787,
#  'mail': 1466,
#  'sent': 2244,
#  'forwarded': 1007,
#  'address': 34,
#  'dots': 740,
#  'rule': 2189,
#  'apply': 108,
#  'allows': 65,
#  'certain': 345,
#  'send': 2243,
#  'addresses': 35,
#  'actually': 23,
#  'names': 1596,
#  'problem': 1914,
#  'minimize': 1538,
#  'malware': 1473,
#  'differences': 686,
#  'network': 1613,
#  'directly': 701,
#  'infected': 1210,
#  'spread': 2384,
#  'continue': 520,
#  'connections': 485,
#  'removed': 2072,
#  'graph': 1069,
#  'considering': 493,
#  'monotone': 1564,
#  'followed': 986,
#  'alternatively': 77,
#  'friend': 1019,
#  'typing': 2671,
#  'long': 1438,
#  'typed': 2668,
#  'examine': 866,
#  'friends': 1021,
#  'pressed': 1892,
#  'necessary': 1601,
#  'press': 1891,
#  'later': 1348,
#  'enumerating': 829,
#  'written': 2828,
#  'music': 1581,
#  'wants': 2780,
#  'listen': 1409,
#  'playlist': 1835,
#  'song': 2351,
#  'played': 1831,
#  'initialized': 1218,
#  'initializes': 1219,
#  'inserted': 1227,
#  'connects': 486,
#  'beginning': 196,
#  'buffer': 267,
#  'universal': 2696,
#  'partitioning': 1754,
#  'groups': 1087,
#  'undirected': 2684,
#  'mouse': 1568,
#  'alternate': 73,
#  'ab': 1,
#  'cat': 330,
#  'hole': 1141,
#  'meets': 1514,
#  'occupies': 1658,
#  'ascending': 130,
#  'cast': 329,
#  'election': 787,
#  'votes': 2765,
#  'vote': 2764,
#  'tied': 2568,
#  'ties': 2569,
#  'continues': 521,
#  'alternating': 76,
#  'board': 230,
#  'destination': 664,
#  'simulates': 2305,
#  'standard': 2400,
#  'die': 682,
#  'regardless': 2055,
#  'snake': 2341,
#  'ladder': 1332,
#  'decide': 603,
#  'ranges': 1991,
#  'minimums': 1542,
#  'superpalindromes': 2496,
#  'outputs': 1704,
#  'piece': 1806,
#  'fruit': 1025,
#  'basket': 190,
#  'carry': 325,
#  'quantity': 1956,
#  'collect': 419,
#  'started': 2404,
#  'eighth': 783,
#  'seven': 2265,
#  'stockspanner': 2426,
#  'collects': 422,
#  'daily': 593,
#  'price': 1898,
#  'quotes': 1975,
#  'span': 2362,
#  'today': 2584,
#  'going': 1063,
#  'stock': 2425,
#  'spans': 2363,
#  'reduced': 2045,
#  'iterator': 1291,
#  'iterates': 1288,
#  'encoded': 799,
#  'encoding': 801,
#  'exhausts': 886,
#  'exhausted': 885,
#  'read': 2008,
#  'rleiterator': 2154,
#  'maps': 1480,
#  'terms': 2548,
#  'returning': 2130,
#  'term': 2545,
#  'obtaining': 1655,
#  'bitwise': 220,
#  'counted': 555,
#  'yield': 2850,
#  'leftmost': 1365,
#  'monotonic': 1565,
#  'pushes': 1946,
#  'removes': 2074,
#  'frequent': 1016,
#  'tie': 2567,
#  'stack': 2392,
#  ...}

# %%
data['content'][1]
# Out:
# "['Given', 'two', 'strings', 'shortest', 'string', 'multiple', 'answers', 'may', 'return', 'string', 'S', 'subsequence', 'string', 'T', 'deleting', 'number', 'characters', 'T', 'characters', 'chosen', 'anywhere', 'results', 'string', 'Example', 'substring', 'delete', 'first', 'substring', 'delete', 'last', 'The', 'answer', 'provided', 'shortest', 'string', 'satisfies', 'consist', 'lowercase', 'English']"

# %%
# generating the cosine similarity matrix
cosine_sim = cosine_similarity(count_mat, count_mat)

#Construct a reverse map of indices and movie titles
indices = pd.Series(data.index, index=data['name']).drop_duplicates()
idx = pd.Series(data.index, index=data['name']).drop_duplicates()

# %%
cosine_sim
# Out:
# array([[1.        , 0.12615514, 0.1768919 , ..., 0.32699929, 0.06280743,
#         0.14322297],
#        [0.12615514, 1.        , 0.12087737, ..., 0.21068313, 0.07725393,
#         0.11744404],
#        [0.1768919 , 0.12087737, 1.        , ..., 0.16113553, 0.03610791,
#         0.04116935],
#        ...,
#        [0.32699929, 0.21068313, 0.16113553, ..., 1.        , 0.02860648,
#         0.06523281],
#        [0.06280743, 0.07725393, 0.03610791, ..., 0.02860648, 1.        ,
#         0.35082321],
#        [0.14322297, 0.11744404, 0.04116935, ..., 0.06523281, 0.35082321,
#         1.        ]])

# %%
def get_recommendations(title, cosine_sim=cosine_sim):
    # get the idx of the movie that matches the title
    movie_idx = idx[title]
    # get the pairwise similarity scores with that movie
    sim_scores = list(enumerate(cosine_sim[movie_idx]))
    # sort
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]
    res_idx = [i[0] for i in sim_scores]
    
    return data['name'].iloc[res_idx]

# %%
get_recommendations('LRU Cache')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-286dfb8d9f39> in <module>
# ----> 1 get_recommendations('LRU Cache')
#
# <ipython-input-19-b4e33250f7d0> in get_recommendations(title, cosine_sim)
#      11
#      12     # gettin the index of the movie that matches the title
# ---> 13     idx = indices[indices == name].index[0]
#      14
#      15     # creating a Series with the similarity scores in descending order
#
# NameError: name 'name' is not defined

# %%
get_recommendations('LFU Cache')
# Out:
# 728                       LRU Cache
# 540        All O`one Data Structure
# 274                  Design HashMap
# 380                   Map Sum Pairs
# 581    Insert Delete GetRandom O(1)
# 275                  Design HashSet
# 459     Convert BST to Greater Tree
# 690    Implement Trie (Prefix Tree)
# 83       Time Based Key-Value Store
# 343                 My Calendar III
# Name: name, dtype: object

# %%
get_recommendations('Merge k Sorted Lists')
# Out:
# 853                       Merge Two Sorted Lists
# 87                     Squares of a Sorted Array
# 786                           Merge Sorted Array
# 791           Remove Duplicates from Sorted List
# 529                           Add Two Numbers II
# 765    Convert Sorted List to Binary Search Tree
# 792        Remove Duplicates from Sorted List II
# 872                              Add Two Numbers
# 254                           Design Linked List
# 855             Remove Nth Node From End of List
# Name: name, dtype: object
