# %%
import pandas as pd
# Import TfIdfVectorizer from scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
# Load Movies Metadata
data = pd.read_csv('../data/leetcode_data_processed_synset.csv', low_memory=False)

# %%
tfidf = TfidfVectorizer()
data['content'] = data['content'].fillna('')
tfidf_matrix = tfidf.fit_transform(data['content'])
tfidf_matrix.shape
# Out:
# (874, 4396)

# %%
tfidf.vocabulary_
# Out:
# {'square': 3754,
#  '01': 0,
#  '02': 1,
#  'public_square': 3137,
#  '04': 3,
#  '05': 4,
#  '06': 5,
#  '07': 6,
#  '08': 7,
#  '03': 2,
#  'feather': 1666,
#  'straight': 3821,
#  'hearty': 1994,
#  'squarely': 3755,
#  'cell': 734,
#  'cellular_telephone': 736,
#  'either': 1453,
#  'empty': 1477,
#  'vacate': 4245,
#  'evacuate': 1548,
#  'barricade': 420,
#  'obstruct': 2734,
#  'stop': 3810,
#  'jam': 2248,
#  'block': 534,
#  'stuff': 3846,
#  '11': 10,
#  'parry': 2858,
#  'forget': 1790,
#  '14': 13,
#  '15': 14,
#  'freeze': 1822,
#  'blocked': 536,
#  'length': 2359,
#  'duration': 1420,
#  'distance': 1344,
#  'compose': 931,
#  'write': 4380,
#  'frame': 1814,
#  'composed': 932,
#  'adjacent': 134,
#  'connect': 967,
#  'associate': 330,
#  'get_in_touch': 1879,
#  'plug_in': 2987,
#  'affiliated': 152,
#  'connected': 968,
#  'machine': 2463,
#  'accessible': 87,
#  'different': 1287,
#  'unlike': 4209,
#  'edge': 1440,
#  'boundary': 580,
#  'border': 572,
#  'location': 2418,
#  'placement': 2957,
#  'localization': 2414,
#  'value': 4252,
#  'prize': 3092,
#  'respect': 3363,
#  'measure': 2524,
#  'rate': 3222,
#  'locate': 2416,
#  'situate': 3646,
#  'settle': 3570,
#  'located': 2417,
#  'tax_return': 3956,
#  'return': 3383,
#  'restitution': 3369,
#  'recurrence': 3277,
#  'rejoinder': 3305,
#  'return_key': 3384,
#  '10': 9,
#  '12': 11,
#  'reappearance': 3243,
#  'render': 3324,
#  'revert': 3393,
#  'hark_back': 1976,
#  'retort': 3381,
#  'come_back': 890,
#  'refund': 3295,
#  'reelect': 3285,
#  'fall': 1643,
#  '21': 20,
#  '16': 15,
#  'short': 3599,
#  'inadequate': 2120,
#  'unretentive': 4216,
#  'light': 2379,
#  '18': 17,
#  '09': 8,
#  'brusque': 622,
#  'clear': 826,
#  'open': 2758,
#  'unclutter': 4170,
#  'clear_up': 827,
#  'authorize': 363,
#  'pass': 2872,
#  'net': 2679,
#  'gain': 1850,
#  '17': 16,
#  'acquit': 110,
#  '19': 18,
#  '20': 19,
#  '22': 21,
#  '23': 22,
#  '24': 23,
#  'clean': 825,
#  'well': 4335,
#  'defined': 1194,
#  '13': 12,
#  'absolved': 75,
#  'clearly': 828,
#  'way': 4320,
#  'path': 2881,
#  'two': 4151,
#  'deuce': 1265,
#  'string_section': 3834,
#  'string': 3833,
#  'bowed_stringed_instrument': 585,
#  'drawstring': 1401,
#  'chain': 746,
#  'multiple': 2631,
#  'answer': 246,
#  'solution': 3702,
#  'suffice': 3877,
#  'may': 2520,
#  'whitethorn': 4340,
#  'sequel': 3556,
#  'posteriority': 3030,
#  'delete': 1200,
#  'erase': 1534,
#  'edit': 1441,
#  'number': 2717,
#  'act': 112,
#  'phone_number': 2925,
#  'numeral': 2720,
#  'issue': 2243,
#  'total': 4056,
#  'count': 1058,
#  'fictional_character': 1684,
#  'quality': 3166,
#  'character': 763,
#  'chosen': 798,
#  'choose': 797,
#  'anywhere': 250,
#  'consequence': 973,
#  'result': 3376,
#  'resultant_role': 3377,
#  'leave': 2344,
#  'substring': 3865,
#  'first': 1718,
#  'beginning': 462,
#  'first_base': 1719,
#  'first_gear': 1720,
#  'inaugural': 2121,
#  'foremost': 1788,
#  'stopping_point': 3814,
#  'last': 2317,
#  'death': 1157,
#  'end': 1490,
#  'survive': 3913,
#  'concluding': 950,
#  'final': 1701,
#  'supply': 3894,
#  'provide': 3135,
#  'put_up': 3156,
#  'satisfy': 3485,
#  'meet': 2532,
#  'dwell': 1421,
#  'consist': 978,
#  'small_letter': 3677,
#  'lowercase': 2453,
#  'english': 1505,
#  'set': 3566,
#  'stage_set': 3758,
#  'bent': 479,
#  'hardening': 1975,
#  'put': 3152,
#  'determine': 1262,
#  'specify': 3728,
#  'fix': 1727,
#  'arrange': 296,
#  'plant': 2966,
#  'jell': 2251,
#  'typeset': 4153,
#  'sic': 3612,
#  'place': 2955,
#  'rig': 3408,
#  'set_up': 3568,
#  'adjust': 135,
#  'fructify': 1837,
#  'dress': 1402,
#  'fit': 1723,
#  'fixed': 1729,
#  'laid': 2302,
#  'determined': 1263,
#  'hardened': 1974,
#  'item': 2245,
#  'detail': 1257,
#  'token': 4047,
#  'label': 2294,
#  'tag': 3936,
#  'pronounce': 3120,
#  'subset': 3861,
#  'every': 1559,
#  'large': 2313,
#  'bombastic': 562,
#  'big': 501,
#  'possible': 3023,
#  'potential': 3034,
#  'sum': 3882,
#  'kernel': 2277,
#  'union': 4195,
#  'summarize': 3884,
#  'values': 4254,
#  'fifth': 1688,
#  'one': 2757,
#  'third': 4001,
#  'third_base': 4002,
#  'third_gear': 4003,
#  'fourth': 1806,
#  'fourthly': 1808,
#  'avaricious': 371,
#  'avid': 373,
#  'greedy': 1929,
#  'repair': 3328,
#  'fasten': 1660,
#  'cook': 1035,
#  'pay_back': 2889,
#  'fixate': 1728,
#  'sterilize': 3792,
#  'extra': 1621,
#  'duplicate': 1419,
#  'twin': 4149,
#  'double': 1384,
#  'happening': 1969,
#  'occurrence': 2741,
#  'shift': 3588,
#  'switch': 3921,
#  'transfer': 4077,
#  'stir': 3804,
#  'careen': 704,
#  'lurch': 2460,
#  'shifting': 3590,
#  'stay': 3783,
#  'remain': 3315,
#  'persist': 2917,
#  'leftover': 2350,
#  'elements': 1462,
#  'component': 930,
#  'chemical_element': 779,
#  'element': 1460,
#  'note': 2706,
#  'bill': 504,
#  'eminence': 1472,
#  'notice': 2710,
#  'beyond': 494,
#  'master': 2503,
#  'original': 2788,
#  'array': 300,
#  'range': 3214,
#  'align': 191,
#  'alteration': 210,
#  'modification': 2598,
#  'change': 753,
#  'input_signal': 2170,
#  'remark': 3318,
#  'stimulation': 3800,
#  'input': 2169,
#  'career': 705,
#  'name': 2650,
#  'call': 671,
#  'shout': 3605,
#  'visit': 4289,
#  'address': 129,
#  'bid': 498,
#  'predict': 3050,
#  '25': 24,
#  '26': 25,
#  '27': 26,
#  '28': 27,
#  'modify': 2600,
#  'modified': 2599,
#  'limited': 2388,
#  'tile': 4024,
#  'matchless': 2508,
#  'letter': 2363,
#  'print': 3083,
#  'sequence': 3557,
#  'succession': 3871,
#  'letters': 2364,
#  'capital': 692,
#  'uppercase': 4227,
#  'backtrack': 388,
#  'small': 3676,
#  'minor': 2578,
#  'little': 2407,
#  'humble': 2055,
#  'modest': 2596,
#  'belittled': 468,
#  'text': 3987,
#  'textbook': 3988,
#  'incorporate': 2128,
#  'hold': 2029,
#  'control': 1018,
#  'contain': 994,
#  'check': 772,
#  'distinct': 1347,
#  'discrete': 1321,
#  'cut': 1129,
#  'precisely': 3047,
#  'binary_star': 508,
#  'binary': 507,
#  'see': 3537,
#  'study': 3845,
#  'consider': 976,
#  'think': 3999,
#  'regard': 3297,
#  'view': 4283,
#  'root': 3435,
#  'ancestor': 236,
#  'etymon': 1546,
#  'rout': 3449,
#  'leaf': 2336,
#  'flick': 1742,
#  'node': 2697,
#  'lymph_node': 2461,
#  'insufficient': 2181,
#  'intersect': 2214,
#  'decussate': 1182,
#  'strictly': 3831,
#  'rigorously': 3413,
#  'lupus_erythematosus': 2459,
#  'less': 2361,
#  'nod': 2696,
#  'limit': 2386,
#  'terminus_ad_quem': 3979,
#  'restrict': 3373,
#  'tree': 4105,
#  'corner': 1047,
#  'words': 4365,
#  'lyric': 2462,
#  'quarrel': 3170,
#  'actor': 118,
#  's_line': 3470,
#  'word': 4364,
#  'news': 2686,
#  'discussion': 1323,
#  'parole': 2856,
#  'son': 3707,
#  'password': 2876,
#  'bible': 496,
#  'give_voice': 1889,
#  'form': 1791,
#  'kind': 2282,
#  'shape': 3579,
#  'human_body': 2054,
#  'phase': 2923,
#  'class': 823,
#  'mannequin': 2485,
#  'imprint': 2108,
#  'second': 3526,
#  'moment': 2605,
#  'second_base': 3527,
#  'second_gear': 3528,
#  'irregular': 2239,
#  'semen': 3545,
#  'come': 889,
#  'arrive': 303,
#  'issue_forth': 2244,
#  'hail': 1957,
#  'occur': 2740,
#  'derive': 1237,
#  'do': 1364,
#  'immediately': 2092,
#  'attention_deficit_disorder': 355,
#  'add': 125,
#  'lend': 2357,
#  'good': 1910,
#  'commodity': 901,
#  'full': 1842,
#  'estimable': 1543,
#  'beneficial': 477,
#  'adept': 130,
#  'dear': 1156,
#  'dependable': 1228,
#  'effective': 1445,
#  'thoroughly': 4006,
#  'girl': 1885,
#  'female_child': 1674,
#  'daughter': 1148,
#  'girlfriend': 1886,
#  'rock': 3424,
#  'rock_candy': 3426,
#  'rock_': 3425,
#  '_roll': 57,
#  'space': 3719,
#  'outer_space': 2803,
#  'quad': 3160,
#  'separate': 3553,
#  'distinguish': 1349,
#  'divide': 1357,
#  'classify': 824,
#  'break': 595,
#  'discriminate': 1322,
#  'branch': 591,
#  'detached': 1256,
#  'separated': 3554,
#  'disjointed': 1330,
#  'numbers': 2718,
#  'numbers_pool': 2719,
#  'base': 424,
#  'foundation': 1803,
#  'floor': 1751,
#  'basis': 433,
#  'nucleotide': 2715,
#  'al': 182,
#  'qaeda': 3159,
#  'infrastructure': 2158,
#  'establish': 1540,
#  'free': 1817,
#  'basal': 423,
#  'significant': 3625,
#  'meaning': 2522,
#  'spot': 3750,
#  'bit': 515,
#  'piece': 2937,
#  'morsel': 2613,
#  'snatch': 3688,
#  'bite': 516,
#  'sting': 3801,
#  'least': 2343,
#  'represent': 3340,
#  'typify': 4155,
#  'exemplify': 1581,
#  'constitute': 985,
#  'defend': 1191,
#  'stage': 3757,
#  'present': 3060,
#  'map': 2490,
#  'format': 1793,
#  'besides': 482,
#  'guarantee': 1943,
#  'undertake': 4181,
#  'lead': 2332,
#  'leadership': 2334,
#  'run': 3457,
#  'head': 1988,
#  'contribute': 1016,
#  'conduct': 955,
#  'go': 1901,
#  'precede': 3042,
#  'moderate': 2593,
#  'leading': 2335,
#  'ahead': 171,
#  'end_product': 1492,
#  'output': 2807,
#  'output_signal': 2808,
#  'nothing': 2708,
#  'zero': 4394,
#  'mathematics': 2512,
#  'matrix': 2513,
#  'column': 884,
#  'somersault': 3705,
#  'flip': 1745,
#  'throw': 4016,
#  'interchange': 2192,
#  'impudent': 2112,
#  'variety': 4260,
#  'exchange': 1571,
#  'deepen': 1187,
#  'maximum': 2519,
#  'utmost': 4243,
#  'maximal': 2517,
#  'row': 3452,
#  'course': 1066,
#  'rowing': 3453,
#  'peer': 2894,
#  'equal': 1526,
#  'adequate': 131,
#  'say': 3492,
#  'state': 3776,
#  'allege': 197,
#  'suppose': 3898,
#  'read': 3235,
#  'order': 2778,
#  'watershed': 4318,
#  'concatenate': 942,
#  'target': 3952,
#  'prey': 3073,
#  'aim': 173,
#  'four': 1805,
#  'asset': 325,
#  'summation': 3886,
#  'plus': 2990,
#  'rearrange': 3245,
#  'pile': 2941,
#  'batch': 438,
#  'bus': 647,
#  'heap': 1992,
#  'stack': 3756,
#  'sort': 3710,
#  'screen': 3515,
#  'positive': 3020,
#  'convinced': 1033,
#  'incontrovertible': 2126,
#  'positivist': 3021,
#  'cocksure': 860,
#  'integer': 2182,
#  'necessarily': 2664,
#  'inevitably': 2146,
#  'substitution': 3864,
#  'permutation': 2912,
#  'smaller': 3678,
#  'make': 2475,
#  'induce': 2143,
#  'cause': 729,
#  'produce': 3103,
#  'draw': 1397,
#  'create': 1082,
#  'reach': 3234,
#  'construct': 987,
#  'have': 1984,
#  'lay_down': 2329,
#  'take': 3941,
#  'stool': 3809,
#  '30': 29,
#  '31': 30,
#  '32': 31,
#  '33': 32,
#  '34': 33,
#  '35': 34,
#  '36': 35,
#  '37': 36,
#  '38': 37,
#  'seduce': 3536,
#  '41': 40,
#  '42': 41,
#  '43': 42,
#  '44': 43,
#  '45': 44,
#  '46': 45,
#  '47': 46,
#  '48': 47,
#  '49': 48,
#  'made': 2465,
#  'barter': 422,
#  'trade': 4067,
#  'swap': 3916,
#  'central': 741,
#  'rally': 3208,
#  'switch_over': 3923,
#  'substitute': 3863,
#  'commute': 904,
#  'position': 3019,
#  'military_position': 2563,
#  'status': 3782,
#  'situation': 3647,
#  'side': 3613,
#  'stead': 3784,
#  'already': 208,
#  'bookshop': 568,
#  'owner': 2832,
#  'shop': 3598,
#  'store': 3815,
#  'memory': 2538,
#  'storehouse': 3816,
#  'outdoors': 2801,
#  'unfold': 4186,
#  'afford': 156,
#  'exposed': 1610,
#  'assailable': 320,
#  'loose': 2441,
#  'receptive': 3256,
#  'overt': 2826,
#  'capable': 688,
#  'candid': 681,
#  'customer': 1127,
#  'enter': 1512,
#  'enroll': 1510,
#  'figure': 1691,
#  'record': 3268,
#  'accede': 81,
#  'insert': 2171,
#  'embark': 1466,
#  'farewell': 1652,
#  'exit': 1590,
#  'entrust': 1518,
#  'bequeath': 480,
#  'impart': 2094,
#  'goal': 1904,
#  'conclusion': 951,
#  'crabbed': 1076,
#  'otherwise': 2795,
#  'differently': 1288,
#  'minute': 2581,
#  'hour': 2050,
#  'infinitesimal': 2151,
#  'know': 2291,
#  'acknowledge': 105,
#  'sleep_together': 3661,
#  'secret': 3530,
#  'mystery': 2648,
#  'clandestine': 820,
#  'unavowed': 4163,
#  'hidden': 2014,
#  'privy': 3091,
#  'confidential': 957,
#  'mysterious': 2647,
#  'technique': 3961,
#  'proficiency': 3107,
#  'support': 3895,
#  'keep': 2273,
#  'continue': 1011,
#  'prevent': 3070,
#  'observe': 2732,
#  'retain': 3379,
#  'sustain': 3914,
#  'restrain': 3371,
#  'keep_open': 2274,
#  'preserve': 3062,
#  'use': 4236,
#  'function': 1846,
#  'consumption': 992,
#  'habit': 1955,
#  'manipulation': 2484,
#  'practice': 3040,
#  'satisfied': 3484,
#  'quenched': 3177,
#  'throughout': 4015,
#  'passim': 2874,
#  'student': 3844,
#  'scholar': 3506,
#  'ask': 316,
#  'necessitate': 2666,
#  'stand': 3767,
#  'rack': 3198,
#  'point_of_view': 2995,
#  'stall': 3764,
#  'bandstand': 405,
#  'digest': 1291,
#  'resist': 3358,
#  'ordering': 2781,
#  'orderliness': 2782,
#  'decree': 1181,
#  'club': 853,
#  'holy_order': 2033,
#  'regulate': 3303,
#  'ordain': 2777,
#  'high': 2015,
#  'height': 1998,
#  'acme': 106,
#  'stature': 3781,
#  'altitude': 215,
#  'annual': 244,
#  'minimum': 2577,
#  'minimal': 2574,
#  'standing': 3770,
#  'right': 3409,
#  'right_field': 3410,
#  'correct': 1048,
#  'proper': 3122,
#  'veracious': 4265,
#  'properly': 3123,
#  'mighty': 2561,
#  'justly': 2271,
#  'correctly': 1049,
#  'must': 2642,
#  'mustiness': 2643,
#  'move': 2621,
#  'motion': 2614,
#  'travel': 4093,
#  'be_active': 447,
#  'affect': 148,
#  'motivate': 2615,
#  'collection': 874,
#  'solicitation': 3699,
#  'knock': 2289,
#  'smash': 3680,
#  'overhead': 2820,
#  'crash': 1078,
#  'hit': 2025,
#  'bankrupt': 410,
#  'crush': 1107,
#  'bang_up': 407,
#  'speculate': 3730,
#  'presuppose': 3067,
#  'stone': 3808,
#  'gem': 1866,
#  'pit': 2950,
#  'weight': 4331,
#  'system_of_weights': 3932,
#  'weight_unit': 4332,
#  'burden': 645,
#  'slant': 3658,
#  'wholly': 4342,
#  'new': 2683,
#  'fresh': 1826,
#  'raw': 3231,
#  'newfangled': 2684,
#  'modern': 2594,
#  'newly': 2685,
#  'combine': 886,
#  'trust': 4128,
#  'combining': 888,
#  'unite': 4200,
#  'compound': 934,
#  'aggregate': 165,
#  'blend': 532,
#  'get': 1877,
#  'become': 455,
#  'receive': 3252,
#  'bring': 607,
#  'experience': 1596,
#  'grow': 1939,
#  'contract': 1015,
#  'drive': 1409,
#  'catch': 723,
#  'scram': 3511,
#  '29': 28,
#  'perplex': 2915,
#  'get_down': 1878,
#  'suffer': 3876,
#  'beget': 459,
#  'convert': 1027,
#  'optimum': 2771,
#  'list': 2399,
#  'tilt': 4027,
#  'predecessor': 3049,
#  'harbinger': 1971,
#  'brand': 592,
#  'shuffle': 3609,
#  'long': 2430,
#  'retentive': 3380,
#  'farseeing': 1655,
#  'longest': 2433,
#  'removal': 3321,
#  'repeatedly': 3330,
#  'longer': 2432,
#  'final_examination': 1702,
#  'remove': 3322,
#  'get_rid_of': 1881,
#  'take_out': 3943,
#  'absent': 71,
#  'murder': 2635,
#  'push': 3150,
#  'down_list': 1390,
#  'smokestack': 3681,
#  'down_storage': 1391,
#  'happen': 1968,
#  'partition': 2868,
#  'division': 1362,
#  'changed': 758,
#  'graph': 1917,
#  'labeled': 2295,
#  'privation': 3090,
#  'lack': 2298,
#  'need': 2670,
#  'wish': 4358,
#  'desire': 1251,
#  'want': 4307,
#  'implant': 2099,
#  'type': 4152,
#  'describe': 1243,
#  'report': 3336,
#  'trace': 4064,
#  'identify': 2077,
#  'being': 465,
#  'universe': 4207,
#  'bidirectional': 500,
#  'garden': 1858,
#  'approach': 270,
#  'advent': 144,
#  'orgasm': 2785,
#  'approaching': 273,
#  'departure': 1226,
#  'undertaking': 4182,
#  'job': 2253,
#  'task': 3953,
#  'tax': 3955,
#  'flower': 1753,
#  'bloom': 538,
#  'choice': 796,
#  'option': 2772,
#  'infinite': 2149,
#  'countless': 1062,
#  'initially': 2163,
#  'face': 1630,
#  'expression': 1613,
#  'grimace': 1934,
#  'font': 1771,
#  'boldness': 560,
#  'confront': 963,
#  'front': 1833,
#  'automaton': 365,
#  'pick_up': 2933,
#  'welcome': 4333,
#  'three': 4013,
#  'trey': 4107,
#  'adam': 122,
#  'crack': 1077,
#  'proceed': 3099,
#  'sound': 3712,
#  'run_low': 3460,
#  'die': 1284,
#  'belong': 470,
#  'start': 3772,
#  'rifle': 3407,
#  'plump': 2988,
#  'fail': 1637,
#  'heterosexual': 2011,
#  'straightaway': 3822,
#  'uncoiled': 4171,
#  'true': 4125,
#  'neat': 2663,
#  'directly': 1303,
#  'bend': 476,
#  'turn': 4137,
#  'turning': 4142,
#  'twist': 4150,
#  'change_state': 756,
#  'change_by_reversal': 754,
#  'plow': 2984,
#  'flex': 1741,
#  'call_on': 672,
#  'sour': 3714,
#  'degree': 1197,
#  'academic_degree': 80,
#  'perform': 2904,
#  'instruction_manual': 2179,
#  'direction': 1302,
#  'education': 1443,
#  'teaching': 3957,
#  'instruction': 2178,
#  'repeat': 3329,
#  'recur': 3276,
#  'reprise': 3344,
#  'truthful': 4129,
#  'genuine': 1873,
#  'on': 2756,
#  'key': 2278,
#  'exist': 1587,
#  'circle': 804,
#  'lap': 2309,
#  'traffic_circle': 4068,
#  'encircle': 1481,
#  'airplane': 180,
#  'plane': 2963,
#  'flat': 1733,
#  'never': 2682,
#  'repetition': 3332,
#  'remains': 3317,
#  'cadaver': 664,
#  'radius': 3203,
#  'spoke': 3747,
#  'focus_on': 1763,
#  'concentrate': 945,
#  'center': 737,
#  'centered': 739,
#  'false': 1648,
#  'delusive': 1205,
#  'fake': 1642,
#  'assumed': 337,
#  'faithlessly': 1641,
#  'north': 2704,
#  'boomerang': 570,
#  'backfire': 383,
#  'point': 2994,
#  'compass_point': 913,
#  'period': 2907,
#  'decimal_point': 1167,
#  'distributor_point': 1353,
#  'indicate': 2137,
#  'orient': 2786,
#  'charge': 764,
#  'steer': 3786,
#  'bespeak': 484,
#  'luff': 2455,
#  'sharpen': 3583,
#  'search': 3522,
#  'research': 3351,
#  'greater': 1927,
#  'great': 1926,
#  'bang': 406,
#  'up': 4221,
#  'left': 2347,
#  'left_field': 2348,
#  'cry': 1108,
#  'birdcall': 513,
#  'margin_call': 2494,
#  'call_option': 673,
#  'end_point': 1491,
#  'picking': 2934,
#  'cream': 1080,
#  'woof': 4363,
#  'pick': 2932,
#  'blame': 522,
#  'foot': 1772,
#  'pluck': 2986,
#  'peck': 2892,
#  'nibble': 2691,
#  'unoccupied': 4214,
#  'moving': 2625,
#  'still': 3799,
#  'hush': 2061,
#  'distillery': 1346,
#  'calm': 676,
#  'inactive': 2119,
#  'silent': 3627,
#  'placid': 2958,
#  'however': 2053,
#  'even': 1554,
#  'game': 1854,
#  'plot': 2983,
#  'bet_on': 487,
#  'crippled': 1090,
#  'back': 381,
#  'to': 4039,
#  'consecutive': 971,
#  'coating': 859,
#  'polish': 3003,
#  'finish': 1711,
#  'ending': 1494,
#  'complete': 922,
#  'finish_up': 1712,
#  'eat_up': 1436,
#  'notification': 2711,
#  'poster': 3029,
#  'detect': 1259,
#  'comment': 898,
#  'illegal': 2083,
#  'convex': 1028,
#  'polygon': 3008,
#  'vertex': 4270,
#  'clockwise': 842,
#  'triangulate': 4110,
#  'triangle': 4109,
#  'triangulum': 4112,
#  'entire': 1513,
#  'mark': 2495,
#  'score': 3510,
#  'grudge': 1942,
#  'sexual_conquest': 3573,
#  'grade': 1915,
#  'triangulation': 4111,
#  'achieve': 102,
#  'million': 2569,
#  'coordinate': 1041,
#  'organize': 2784,
#  'grid': 1931,
#  'power_system': 3038,
#  'startle': 3775,
#  'starting_signal': 3774,
#  'begin': 461,
#  'depart': 1223,
#  'originate': 2790,
#  'source': 3715,
#  'informant': 2154,
#  'generator': 1871,
#  'reservoir': 3354,
#  'reference': 3287,
#  'scope': 3508,
#  'compass': 912,
#  'strive': 3837,
#  'walk': 4303,
#  'base_on_balls': 425,
#  'walk_of_life': 4304,
#  'inaccessible': 2118,
#  'starting': 3773,
#  'outside': 2810,
#  'external': 1619,
#  'outdoor': 2800,
#  'away': 375,
#  'publish': 3139,
#  'spell': 3734,
#  'offprint': 2750,
#  'freestanding': 1821,
#  'disjoined': 1328,
#  'horizontal': 2045,
#  'drawing_card': 1399,
#  'hook': 2040,
#  'pull': 3141,
#  'reap': 3242,
#  'puff': 3140,
#  'withdraw': 4359,
#  'absorb': 76,
#  'attract': 358,
#  'pull_back': 3142,
#  'guide': 1949,
#  'tie': 4021,
#  'disembowel': 1324,
#  'line': 2389,
#  'argumentation': 285,
#  'cable': 660,
#  'wrinkle': 4379,
#  'pipeline': 2949,
#  'telephone_line': 3963,
#  'lineage': 2391,
#  'occupation': 2737,
#  ...}

# %%
data['content'][1]
# Out:
# 'two strings shortest string multiple answers may return string subsequence string deleting number characters characters chosen anywhere results string substring delete first substring delete last answer provided shortest string satisfies consist lowercase english dynamic programming'

# %%
# Compute the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

#Construct a reverse map of indices and movie titles
indices = pd.Series(data.index, index=data['name']).drop_duplicates()
idx = pd.Series(data.index, index=data['name']).drop_duplicates()

# %%
idx[:3]
# Out:
# name
# Shortest Path in Binary Matrix    0
# Shortest Common Supersequence     1
# Largest Values From Labels        2
# dtype: int64

# %%
def get_recommendations(title, cosine_sim=cosine_sim):
    # get the idx of the movie that matches the title
    movie_idx = idx[title]
    # get the pairwise similarity scores with that movie
    sim_scores = list(enumerate(cosine_sim[movie_idx]))
    # sort
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]
    res_idx = [i[0] for i in sim_scores]
    
    return data['name'].iloc[res_idx]

# %%
get_recommendations('LRU Cache')
# Out:
# 514                       LFU Cache
# 540        All O`one Data Structure
# 274                  Design HashMap
# 380                   Map Sum Pairs
# 275                  Design HashSet
# 581    Insert Delete GetRandom O(1)
# 690    Implement Trie (Prefix Tree)
# 642                Peeking Iterator
# 459     Convert BST to Greater Tree
# 719                       Min Stack
# Name: name, dtype: object

# %%
get_recommendations('LFU Cache')
# Out:
# 728                       LRU Cache
# 540        All O`one Data Structure
# 274                  Design HashMap
# 380                   Map Sum Pairs
# 275                  Design HashSet
# 581    Insert Delete GetRandom O(1)
# 690    Implement Trie (Prefix Tree)
# 459     Convert BST to Greater Tree
# 719                       Min Stack
# 83       Time Based Key-Value Store
# Name: name, dtype: object

# %%
get_recommendations('Merge k Sorted Lists')
# Out:
# 853                   Merge Two Sorted Lists
# 791       Remove Duplicates from Sorted List
# 855         Remove Nth Node From End of List
# 254                       Design Linked List
# 782                   Reverse Linked List II
# 792    Remove Duplicates from Sorted List II
# 257                   Linked List Components
# 529                       Add Two Numbers II
# 872                          Add Two Numbers
# 661             Delete Node in a Linked List
# Name: name, dtype: object

# %%
get_recommendations('Spiral Matrix')
# Out:
# 486                        Diagonal Traverse
# 815                         Spiral Matrix II
# 310                          Toeplitz Matrix
# 826                             Rotate Image
# 440                       Reshape the Matrix
# 593    Max Sum of Rectangle No Larger Than K
# 800                       Search a 2D Matrix
# 631           Range Sum Query 2D - Immutable
# 455                                01 Matrix
# 160                     Sort Array By Parity
# Name: name, dtype: object

# %%
get_recommendations('Decode Ways')
# Out:
# 410                            Decode Ways II
# 185                   Decoded String at Index
# 576                               Mini Parser
# 677                            Maximal Square
# 122             Find the Shortest Superstring
# 148                      Reverse Only Letters
# 508    Unique Substrings in Wraparound String
# 854                         Valid Parentheses
# 789                         Maximal Rectangle
# 567                             Decode String
# Name: name, dtype: object

# %%
get_recommendations('Two Sum')
# Out:
# 713                   Two Sum II - Input array is sorted
# 679                                Contains Duplicate II
# 299                                        Binary Search
# 858                                         3Sum Closest
# 840    Find First and Last Position of Element in Sor...
# 841                       Search in Rotated Sorted Array
# 856                                                 4Sum
# 632                          Range Sum Query - Immutable
# 793                    Search in Rotated Sorted Array II
# 600                              Top K Frequent Elements
# Name: name, dtype: object

# %%
get_recommendations('01 Matrix')
# Out:
# 35            Matrix Cells in Distance Order
# 486                        Diagonal Traverse
# 354         Find K-th Smallest Pair Distance
# 820                            Spiral Matrix
# 310                          Toeplitz Matrix
# 826                             Rotate Image
# 0             Shortest Path in Binary Matrix
# 593    Max Sum of Rectangle No Larger Than K
# 800                       Search a 2D Matrix
# 763             Minimum Depth of Binary Tree
# Name: name, dtype: object
